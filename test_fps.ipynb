# %%
import numpy as np
import torch
# fps_list = np.load('/home/yining.pan/codefield/misc/lcps/time_list.npy.npz')
fps_list = torch.load('time_list.pth')

# %%
fps_list['post_time']
# Out:
# [0.04555153846740723,
#  0.041959524154663086,
#  0.042474985122680664,
#  0.040719032287597656,
#  0.04368257522583008,
#  0.041413307189941406,
#  0.04032754898071289,
#  0.04285311698913574,
#  0.03989362716674805,
#  0.04345345497131348,
#  0.0409243106842041,
#  0.04062080383300781,
#  0.03952455520629883,
#  0.04529857635498047,
#  0.04199862480163574,
#  0.04044055938720703,
#  0.04057931900024414,
#  0.04026484489440918,
#  0.04026532173156738,
#  0.040749311447143555,
#  0.04035162925720215,
#  0.04040098190307617,
#  0.04022979736328125,
#  0.040487051010131836,
#  0.03922414779663086,
#  0.040062904357910156,
#  0.040232181549072266,
#  0.04192328453063965,
#  0.0437006950378418,
#  0.04069948196411133,
#  0.041194915771484375,
#  0.041202545166015625,
#  0.040685415267944336,
#  0.03938484191894531,
#  0.040525197982788086,
#  0.04062843322753906,
#  0.03940558433532715,
#  0.0384373664855957,
#  0.03808331489562988,
#  0.037412405014038086,
#  0.04330921173095703,
# ...

# %% [markdown]
# ************ LIDAR **************
# FPS total: 4.355421512168426
# FPS data:  0.003996029417634284
# FPS model:  6.074676628255916
# FPS post:  24.641575298692306
# ************************************
#
# ************ MM ****************
# FPS total: 1.642702406364273
# FPS data:  0.001554493731753976
# FPS model:  1.850385773974743
# FPS post:  26.85043159724639
# ************************************
